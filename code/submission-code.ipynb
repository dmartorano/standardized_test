# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** As a high school guidance counselor in the state of Maine, I have observed trends in SAT and ACT score requirements by various colleges--in state and out of state--that my students have expressed interest in. Namely, I have found that, in order for an institution to admit someone (based on test scores), a student generally needs to meet or exceed the average test score of the institution (citation: https://www.collegeadvisor.com/resources/standardized-test-college-test-optional/). I need to use this information to help guide them on whether they should submit test scores to test-optional institutions that are the best fit for them, both academically and personally.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** As a guidance counselor in this situation, it is important to know the various statistics around standardized tests in order to best guide and prepare students for colleges admissions. It is also important to know other aspects about schools, such as whether they are in-state or out-of-state, as schools are often more affordable for in-state students. In order to determine whether a school is in-state or out-of-state, I have acquired location info from the College Scorecard, which is a robust dataset containing a large variety of variables related to post-secondary institutions.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# act_2019.csv - This dataset contains ACT scores and participation rates by state in the year 2019.\
# sat_2019.csv - This dataset contains SAT scores--by section and total--and participation rates by state in the year 2019.\
# sat_act_by_college - This data contains a list of colleges, their test option policies for 2020-2021 or beyond, their acceptance rates and numbers of applicants, and the SAT/ACT score ranges of their applicants.\
# collegescorecard2019locationinfo - This dataset includes location info from the College Scorecard.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:**
# The state of Maine requires all students to take the SAT in their third year of high school, but the ACT is optional. Citation: Personal experience\
# The national average SAT score is about 1010, while the national average ACT score is 19.5. Citations: https://www.princetonreview.com/college-advice/good-sat-scores, https://www.princetonreview.com/college-advice/good-act-scores

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_mean(num_list):
    n = len(num_list)

    numlistsum = sum(num_list)
    listmean = numlistsum / n

    return listmean

find_mean([1,2,3])
# Out:
# 2.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def find_sd(num_list):
    n = len(num_list)
    numlistsum = sum(num_list)
    listmean = numlistsum / n
    deviation = [(x - listmean) ** 2 for x in num_list]
    variance = sum(deviation) / n
    listsd = variance ** .5

    return listsd

find_sd([1,2,3,4,5])
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def per100todec(percent):
    floatable = percent.replace("%", "")
    percdecimal = float(floatable)/100

    return percdecimal
per100todec("65%")
# Out:
# 0.65

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Data Imports
sat2019 = pd.read_csv("../data-used/sat_2019.csv")
act2019 = pd.read_csv("../data-used/act_2019.csv")
satactbycollege = pd.read_csv("../data-used/sat_act_by_college.csv")
collegelocations = pd.read_csv("../data-used/collegescorecard2019locationinfo.csv")

# %%
collegelocations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6694 entries, 0 to 6693
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   INSTNM  6694 non-null   object
#  1   CITY    6694 non-null   object
#  2   STABBR  6694 non-null   object
#  3   ZIP     6694 non-null   object
# dtypes: object(4)
# memory usage: 209.3+ KB

# %%
collegelocations.columns = collegelocations.columns.str.lower()

# %%
collegelocations.columns = collegelocations.columns.str.replace("instnm", "school")

# %%
collegelocations.columns = collegelocations.columns.str.replace("stabbr", "state")

# %%
sat2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
satactbycollege.head()
# Out:
#                  school test_optional applies_to_class_year  \
# 0   Stanford University           Yes                  2021
# 1       Harvard College           Yes                  2021
# 2  Princeton University           Yes                  2021
# 3   Columbia University           Yes                  2021
# 4       Yale University           Yes                  2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   accept_rate sat_total_middle50_percentile act_total_middle50_percentile
# 0        4.3%                     1440-1570                         32-35
# ...

# %%
sat2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
satactbycollege.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        390 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
sat2019.columns = sat2019.columns.str.lower()

# %%
sat2019.columns = sat2019.columns.str.replace(" ","_")

# %%
sat2019.columns = sat2019.columns.str.replace("ebrw", "readingwriting")

# %%
sat2019.head()
# Out:
#         state participation_rate  readingwriting  math  total
# 0     Alabama                 7%             583   560   1143
# 1      Alaska                41%             556   541   1097
# 2     Arizona                31%             569   565   1134
# 3    Arkansas                 6%             582   559   1141
# 4  California                63%             534   531   1065

# %%
act2019.columns = act2019.columns.str.lower()

# %%
act2019.head()
# Out:
#         state participation  composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
satactbycollege.columns = satactbycollege.columns.str.lower()

# %%
satactbycollege.columns = satactbycollege.columns.str.replace(" ", "_")

# %%
satactbycollege.columns = satactbycollege.columns.str.replace("?", "")

# %%
satactbycollege.columns = satactbycollege.columns.str.replace("(s)", "")

# %%
satactbycollege.columns = satactbycollege.columns.str.replace("25th-75th", "middle50")

# %%
satactbycollege.head()
# Out:
#                  school test_optional applies_to_class_year  \
# 0   Stanford University           Yes                  2021
# 1       Harvard College           Yes                  2021
# 2  Princeton University           Yes                  2021
# 3   Columbia University           Yes                  2021
# 4       Yale University           Yes                  2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   accept_rate sat_total_middle50_percentile act_total_middle50_percentile
# 0        4.3%                     1440-1570                         32-35
# ...

# %%
satactbycollege.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   school                         416 non-null    object
#  1   test_optional                  416 non-null    object
#  2   applies_to_class_year          390 non-null    object
#  3   policy_details                 416 non-null    object
#  4   number_of_applicants           416 non-null    int64
#  5   accept_rate                    416 non-null    object
#  6   sat_total_middle50_percentile  416 non-null    object
#  7   act_total_middle50_percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
collegelocations.head()
# Out:
#                                 school        city state         zip
# 0             Alabama A & M University      Normal    AL       35762
# 1  University of Alabama at Birmingham  Birmingham    AL  35294-0110
# 2                   Amridge University  Montgomery    AL  36117-3553
# 3  University of Alabama in Huntsville  Huntsville    AL       35899
# 4             Alabama State University  Montgomery    AL  36104-0271

# %%
collegelocations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6694 entries, 0 to 6693
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   INSTNM  6694 non-null   object
#  1   CITY    6694 non-null   object
#  2   STABBR  6694 non-null   object
#  3   ZIP     6694 non-null   object
# dtypes: object(4)
# memory usage: 209.3+ KB

# %%
satactbycollegewithlocation = pd.merge(satactbycollege, collegelocations, how="inner")

# %%
satactbycollegewithlocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   school                         280 non-null    object
#  1   test_optional                  280 non-null    object
#  2   applies_to_class_year          261 non-null    object
#  3   policy_details                 280 non-null    object
#  4   number_of_applicants           280 non-null    int64
#  5   accept_rate                    280 non-null    object
#  6   sat_total_middle50_percentile  280 non-null    object
#  7   act_total_middle50_percentile  280 non-null    object
#  8   city                           280 non-null    object
#  9   state                          280 non-null    object
#  10  zip                            280 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 24.2+ KB

# %%
satpercentiles = satactbycollegewithlocation["sat_total_middle50_percentile"].str.split("-", expand = True)

# %%
satactbycollegewithlocation["sat_total_25th_percentile"] = satpercentiles[0]
satactbycollegewithlocation["sat_total_75th_percentile"] = satpercentiles[1]

# %%
satactbycollegewithlocation["sat_total_25th_percentile"].str.replace(" ", "")
# Out:
# 0        1440
# 1        1440
# 2        1460
# 3      ​​1530
# 4      ​​1500
#         ...
# 275      1220
# 276      1220
# 277       990
# 278      1050
# 279      1060
# Name: sat_total_25th_percentile, Length: 280, dtype: object

# %%
actpercentiles = satactbycollegewithlocation["act_total_middle50_percentile"].str.split("-", expand = True)

# %%
satactbycollegewithlocation["act_total_25th_percentile"] = actpercentiles[0]
satactbycollegewithlocation["act_total_75th_percentile"] = actpercentiles[1]

# %%
satpercentiles.head()
# Out:
#          0     1     2
# 0     1440  1570  None
# 1     1440  1570  None
# 2     1460  1570  None
# 3  ​​ 1530  1560  None
# 4  ​​ 1500  1570  None

# %%
# satactbycollegewithlocation[["sat_total_25th_percentile", "sat_total_75th_percentile"]] = satactbycollegewithlocation["sat_total_middle50_percentile"].str.split("-", expand = True)
# This code was not working to yield the splitting of the percentile ranges into two columns showing the 25th and 75th percentiles of each test, so I used the code from the cells above.

# %%
satactbycollegewithlocation.head()
# Out:
#                                   school test_optional applies_to_class_year  \
# 0                    Stanford University           Yes                  2021
# 1                   Princeton University           Yes                  2021
# 2                        Yale University           Yes                  2021
# 3     California Institute of Technology      Yes (TB)             2021 2022
# 4  Massachusetts Institute of Technology           Yes                  2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Princeton has adopted a one-year test optional...                 35370
# 2  Yale has adopted a one-year test optional poli...                 36844
# 3  CalTech has adopted a two-year Test Blind poli...                  8367
# 4  MIT has adopted a one-year test optional polic...                 21706
#
# ...

# %%
satactbycollegewithlocation[satactbycollegewithlocation["state"].isin(["ME"])]
# Out:
#                   school test_optional   applies_to_class_year  \
# 10       Bowdoin College           Yes  All / Permanent Policy
# 21         Bates College           Yes  All / Permanent Policy
# 24         Colby College           Yes  All / Permanent Policy
# 252  University of Maine           Yes               2021 2022
#
#                                         policy_details  number_of_applicants  \
# 10   Bowdoin College offers a test optional policy ...                  9332
# 21   Bates offers a test optional policy which allo...                  8222
# 24   Colby College offers a test optional policy wh...                 12313
# 252  University of Maine has adopted a two-year tes...                 13118
#
#     accept_rate sat_total_middle50_percentile act_total_middle50_percentile  \
# 10         8.8%                     1330-1520                         31-34
# 21        12.1%                     1270-1480                         29-33
# ...

# %%
satact2019 = pd.merge(sat2019, act2019, how="inner")

# %%
satact2019.head()
# Out:
#         state participation_rate  readingwriting  math  total participation  \
# 0     Alabama                 7%             583   560   1143          100%
# 1      Alaska                41%             556   541   1097           38%
# 2     Arizona                31%             569   565   1134           73%
# 3    Arkansas                 6%             582   559   1141          100%
# 4  California                63%             534   531   1065           23%
#
#    composite
# 0       18.9
# 1       20.1
# 2       19.0
# 3       19.3
# 4       22.6

# %%
satact2019.columns = satact2019.columns.str.replace("act_sat_participation", "sat_participation")

# %%
satact2019.columns = satact2019.columns.str.replace("participation", "act_participation")

# %%
satact2019.head(25)
# Out:
#                    state sat_participation  readingwriting  math  total  \
# 0                Alabama                7%             583   560   1143
# 1                 Alaska               41%             556   541   1097
# 2                Arizona               31%             569   565   1134
# 3               Arkansas                6%             582   559   1141
# 4             California               63%             534   531   1065
# 5               Colorado              100%             518   506   1024
# 6            Connecticut              100%             529   516   1046
# 7               Delaware              100%             499   486    985
# 8   District of Columbia               94%             495   480    975
# 9                Florida              100%             516   483    999
# 10               Georgia               71%             538   519   1058
# 11                Hawaii               54%             550   550   1100
# ...

# %%
satact2019["sat_participation_float"] = satact2019["sat_participation"].map(per100todec)

# %%
satact2019["act_participation_float"] = satact2019["act_participation"].map(per100todec)

# %%
satact2019.head()
# Out:
#         state sat_participation  readingwriting  math  total  \
# 0     Alabama                7%             583   560   1143
# 1      Alaska               41%             556   541   1097
# 2     Arizona               31%             569   565   1134
# 3    Arkansas                6%             582   559   1141
# 4  California               63%             534   531   1065
#
#   act_participation  composite  sat_participation_float  \
# 0              100%       18.9                     0.07
# 1               38%       20.1                     0.41
# 2               73%       19.0                     0.31
# 3              100%       19.3                     0.06
# 4               23%       22.6                     0.63
#
#    act_participation_float
# 0                     1.00
# 1                     0.38
# 2                     0.73
# 3                     1.00
# 4                     0.23

# %%
satact2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   state                    51 non-null     object
#  1   sat_participation        51 non-null     object
#  2   readingwriting           51 non-null     int64
#  3   math                     51 non-null     int64
#  4   total                    51 non-null     int64
#  5   act_participation        51 non-null     object
#  6   composite                51 non-null     float64
#  7   act_participation_float  51 non-null     float64
#  8   sat_participation_float  51 non-null     float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 3.7+ KB

# %%
satactbycollegewithlocation["accept_rate_float"] = satactbycollegewithlocation["accept_rate"].map(per100todec)

# %%
satactbycollegewithlocation["sat_total_25th_percentile"] = pd.to_numeric(satactbycollegewithlocation["sat_total_25th_percentile"], errors="coerce")
# Unable to determine error "Unable to parse string " 1530" at position 3, but discovered that error is due to "whitespace" through assistance from ChatGPT for debugging,

# %%
satactbycollegewithlocation["sat_total_75th_percentile"] = pd.to_numeric(satactbycollegewithlocation["sat_total_75th_percentile"])

# %%
satactbycollegewithlocation["act_total_25th_percentile"] = pd.to_numeric(satactbycollegewithlocation["act_total_25th_percentile"])

# %%
satactbycollegewithlocation["act_total_75th_percentile"] = pd.to_numeric(satactbycollegewithlocation["act_total_75th_percentile"])

# %%
satactbycollegewithlocation["sat_school_avg"] = satactbycollegewithlocation[["sat_total_25th_percentile", "sat_total_75th_percentile"]].mean(axis = 1)

# %%
satactbycollegewithlocation["act_school_avg"] = satactbycollegewithlocation[["act_total_25th_percentile", "act_total_75th_percentile"]].mean(axis = 1)

# %%
satactbycollegewithlocation["should_scores_be_submitted"] = (satactbycollegewithlocation['sat_school_avg'] == 1013) | (satactbycollegewithlocation['act_school_avg'] == 24.3)

# %%
satactbycollegewithlocation.drop("achievable", axis = 1, inplace = True)

# %%
satactbycollegewithlocation.head(100)
# Out:
#                                    school test_optional  \
# 0                     Stanford University           Yes
# 1                    Princeton University           Yes
# 2                         Yale University           Yes
# 3      California Institute of Technology      Yes (TB)
# 4   Massachusetts Institute of Technology           Yes
# ..                                    ...           ...
# 95             Texas Christian University           Yes
# 96          Southern Methodist University           Yes
# 97                     Providence College           Yes
# 98                  University of Georgia           Yes
# 99                University of San Diego           Yes
#
#      applies_to_class_year                                     policy_details  \
# 0                     2021  Stanford has adopted a one-year test optional ...
# 1                     2021  Princeton has adopted a one-year test optional...
# ...

# %%
satactbycollegewithlocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 0 to 260
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   school                         253 non-null    object
#  1   test_optional                  253 non-null    object
#  2   applies_to_class_year          253 non-null    object
#  3   policy_details                 253 non-null    object
#  4   number_of_applicants           253 non-null    int64
#  5   accept_rate                    253 non-null    object
#  6   sat_total_middle50_percentile  253 non-null    object
#  7   act_total_middle50_percentile  253 non-null    object
#  8   city                           253 non-null    object
#  9   state                          253 non-null    object
#  10  zip                            253 non-null    object
#  11  sat_total_25th_percentile      253 non-null    float64
# ...

# %%
# Null values will make SD formula unable to yield results for the percentile columns, so removing null values will be helpful to ensure accuracy for the rest of the entries.
satactbycollegewithlocation.dropna(inplace=True)

# %%
satact2019.to_csv("../data-used/satact2019.csv")

# %%
satactbycollegewithlocation.to_csv("../data-used/satactbycollegewithlocation.csv")

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|satact2019|This is the two-letter abbreviation of the U.S. state where participation and scores are being tracked|
# |sat_participation|object|satact2019|This is the participation rate by state for the SAT as a percent|
# |readingwriting|int|satact2019|This is the average reading and writing SAT score for the state|
# |math|int|satact2019|This is the average math SAT score for the state|
# |total|int|satact2019|This is the average total SAT score for the state|
# |act_participation|object|satact2019|This is the participation rate by state for the ACT as a percent|
# |composite|float|satact2019|This is the average ACT composite score for the state|
# |sat_participation_float|float|satact2019|This is the SAT participation rate as a float value|
# |act_participation_float|float|satact2019|This is the ACT participation rate as a float value|
# |school|object|satactbycollegewithlocation|This is the name of the post-secondary institution|
# |test_optional|object|satactbycollegewithlocation|This states whether the institution requires the SAT/ACT|
# |applies_to_class_year|object|satactbycollegewithlocation|This states what graduation year the test-optional policy applies to|
# |policy_details|object|satactbycollegewithlocation|This includes specific details about the test-optional policy|
# |number_of_applicants|int|satactbycollegewithlocation|This displays how many individuals applied to the institution|
# |accept_rate|object|satactbycollegewithlocation|This is the rate at which students were accepted based on how many applied|
# |sat_total_middle50_percentile|object|satactbycollegewithlocation|This is the 25-75 percentile range for the SAT score at the institution|
# |act_total_middle50_percentile|object|satactbycollegewithlocation|This is the 25-75 percentile range for the ACT score at the institution|
# |state|object|satactbycollegewithlocation|This shows in what state the institution is located|
# |accept_rate_float|float|satactbycollegewithlocation|This is the acceptance rate of the institution as a float value|
# |sat_total_25th_percentile|float|satactbycollegewithlocation|This is the 25th percentile value for SAT scores of accepted students at the institution|
# |sat_total_75th_percentile|float|satactbycollegewithlocation|This is the 75th percentile value for SAT scores of accepted students at the institution|
# |sat_school_avg|float|satactbycollegewithlocation|This is the average SAT score for this institution|
# |act_total_25th_percentile|float|satactbycollegewithlocation|This is the 25th percentile value for ACT scores of accepted students at the institution|
# |act_total_75th_percentile|float|satactbycollegewithlocation|This is the 75th percentile value for ACT scores of accepted students at the institution|
# |act_school_avg|float|satactbycollegewithlocation|This is the average ACT score for this institution|
# |should_scores_be_submitted|bool|satactbycollegewithlocation|This boolean determines whether an average Maine student should submit test scores to an institution|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
satact2019.describe()
# Out:
#        readingwriting        math        total  composite  \
# count       51.000000   51.000000    51.000000  51.000000
# mean       560.803922  552.196078  1113.078431  21.464706
# std         46.248035   51.290553    97.197910   2.194523
# min        483.000000  460.000000   943.000000  17.900000
# 25%        527.500000  511.500000  1038.000000  19.800000
# 50%        550.000000  546.000000  1097.000000  21.100000
# 75%        612.000000  599.000000  1210.000000  23.700000
# max        636.000000  648.000000  1284.000000  25.500000
#
#        sat_participation_float  act_participation_float
# count                51.000000                51.000000
# mean                  0.490588                 0.586667
# std                   0.387476                 0.345159
# min                   0.020000                 0.060000
# 25%                   0.055000                 0.245000
# 50%                   0.540000                 0.540000
# ...

# %%
satactbycollegewithlocation.describe()
# Out:
#        number_of_applicants  sat_total_25th_percentile  \
# count            280.000000                 272.000000
# mean           13936.832143                1184.637868
# std            13284.866176                 122.655438
# min              211.000000                 793.000000
# 25%             4752.750000                1090.000000
# 50%             9394.000000                1160.000000
# 75%            18995.000000                1271.250000
# max            79462.000000                1490.000000
#
#        sat_total_75th_percentile  act_total_25th_percentile  \
# count                 276.000000                 279.000000
# mean                 1376.612319                  25.513620
# std                   104.798361                   3.961091
# min                  1078.000000                  15.000000
# 25%                  1300.000000                  22.000000
# 50%                  1360.000000                  25.000000
# ...

# %% [markdown]
# Summary stats of satact2019 show statistics of meaningful information, while the summary stats of satactbycollegewithlocation for the percentiles could prove useful.

# %%
sd2019 = {col: find_sd(satact2019[col]) for col in satact2019.columns if satact2019[col].dtype in ["int64", "float64"]} 
# Finds standard deviation of columns in the dataframe for all columns where their datatype is an integer or float, then assigns keys to column names and values to standard deviations of columns
print(sd2019)
# Out:
# {'readingwriting': 45.792378682545134, 'math': 50.78521461840036, 'total': 96.24027185617864, 'composite': 2.172901153595978, 'sat_participation_float': 0.3836584048685726, 'act_participation_float': 0.3417582373703047}

# %%
sdbycollege = {col: find_sd(satactbycollegewithlocation[col]) for col in satactbycollegewithlocation.columns if satactbycollegewithlocation[col].dtype in ["int64", "float64"]} 
print(sdbycollege)
# Out:
# {'number_of_applicants': 13261.121981878174, 'sat_total_25th_percentile': nan, 'sat_total_75th_percentile': nan, 'act_total_25th_percentile': nan, 'act_total_75th_percentile': nan, 'accept_rate_float': 0.24786194970122755, 'sat_school_avg': nan, 'act_school_avg': nan}

# %% [markdown]
# SDs of the satact2019 dataset show some potentially important information, and the SDs of percentile information from the satactbycollegewithlocation could be helpful for guiding students.

# %%
satact2019.loc[satact2019["state"] == "Maine"]
# Knowing that the averages for the SAT and ACT are about 1010 and 19.5 respectively, this information can be used to inform students 
# about where they and their peers lie in relation to average scores, which may be helpful in guiding them toward certain universities.
# Out:
#     state sat_participation  readingwriting  math  total act_participation  \
# 19  Maine               99%             512   502   1013                6%
#
#     composite  sat_participation_float  act_participation_float
# 19       24.3                     0.99                     0.06

# %%
satactbycollegewithlocation.loc[satactbycollegewithlocation["state"] == "ME"]
# Sorting colleges by those in the state of Maine that are included in the dataset can be important in guiding students toward information about in-state colleges and universities
# which may offer better financial aid packages or lower tuition rates than out-of-state schools.
# Out:
#                   school test_optional   applies_to_class_year  \
# 10       Bowdoin College           Yes  All / Permanent Policy
# 21         Bates College           Yes  All / Permanent Policy
# 24         Colby College           Yes  All / Permanent Policy
# 252  University of Maine           Yes               2021 2022
#
#                                         policy_details  number_of_applicants  \
# 10   Bowdoin College offers a test optional policy ...                  9332
# 21   Bates offers a test optional policy which allo...                  8222
# 24   Colby College offers a test optional policy wh...                 12313
# 252  University of Maine has adopted a two-year tes...                 13118
#
#     accept_rate sat_total_middle50_percentile act_total_middle50_percentile  \
# 10         8.8%                     1330-1520                         31-34
# 21        12.1%                     1270-1480                         29-33
# ...

# %%
satact2019[satact2019["total"] > 1013]
# This information is helpful as it shows which states have higher average SAT scores than the state of Maine, which appears to be a considerable amount. 
# However, it's also crucial to note that Maine has mandated the SAT.
# Out:
#              state sat_participation  readingwriting  math  total  \
# 0          Alabama                7%             583   560   1143
# 1           Alaska               41%             556   541   1097
# 2          Arizona               31%             569   565   1134
# 3         Arkansas                6%             582   559   1141
# 4       California               63%             534   531   1065
# 5         Colorado              100%             518   506   1024
# 6      Connecticut              100%             529   516   1046
# 10         Georgia               71%             538   519   1058
# 11          Hawaii               54%             550   550   1100
# 14         Indiana               66%             543   537   1080
# 15            Iowa                3%             622   622   1244
# 16          Kansas                4%             618   623   1241
# 17        Kentucky                4%             620   612   1232
# ...

# %%
satact2019[(satact2019["total"] > 1013) & (satact2019["composite"] > 24.3)]
# This filter shows what states have higher average SAT and ACT scores than Maine, which is a significantly lower number of states, although it is impressive.
# Out:
#             state sat_participation  readingwriting  math  total  \
# 6     Connecticut              100%             529   516   1046
# 21  Massachusetts               81%             559   561   1120
# 29  New Hampshire               95%             533   526   1059
# 32       New York               79%             531   533   1064
#
#    act_participation  composite  sat_participation_float  \
# 6                22%       25.5                     1.00
# 21               21%       25.5                     0.81
# 29               14%       25.0                     0.95
# 32               22%       24.5                     0.79
#
#     act_participation_float
# 6                      0.22
# 21                     0.21
# 29                     0.14
# 32                     0.22

# %%
satactbycollegewithlocation[(satactbycollegewithlocation["should_scores_be_submitted"] == True)]
# Out:
# Empty DataFrame
# Columns: [school, test_optional, applies_to_class_year, policy_details, number_of_applicants, accept_rate, sat_total_middle50_percentile, act_total_middle50_percentile, city, state, zip, sat_total_25th_percentile, sat_total_75th_percentile, act_total_25th_percentile, act_total_75th_percentile, accept_rate_float, sat_school_avg, act_school_avg, should_scores_be_submitted]
# Index: []

# %% [markdown]
# **To-Do:**
# Based on reported and cited information, the state of Maine's average SAT score is lower than average compared to the rest of the country, likely due to the test-taking requirement in high schools. ACT takers in the state, however, score closer to the 75th percentile, likely attributed to the optional nature and therefore the self-determination of the test-takers.\
# The colleges in the state of Maine with the lowest acceptance rates have adopted permanent test-optional policies, but also have significantly higher test scores than the public flagship state university.\
# Many states score above Maine in the average SAT score, but when factoring in both SAT and ACT scores, there are much fewer states that surpass Maine outright.\
# The average Maine SAT and ACT scores do not meet or exceed the average test scores for any of the institutions within the dataset, so an average Maine student should not submit scores to a test-optional school.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize = (10,10))
scorecorr = satact2019.corr(numeric_only = True)

mask = np.zeros_like(scorecorr)
mask[np.triu_indices_from(mask)] = True

ax1 = sns.heatmap(scorecorr, mask = mask, annot = True, vmax = 1, vmin = -1)
ax1.set(title="Correlations Between SAT and ACT Scores")
plt.savefig("../data/Visualizations/heatmapsatact.png")

# %% [markdown]
# ***Interpretation:*** This heatmap shows that, as more students are required to take the SAT or ACT, the average SAT or ACT score for the state tends to trend downward. This would account for low average scores in states where the tests are required, such as Maine.

# %%
plt.figure(figsize = (10,10))
collegecorr = satactbycollegewithlocation.corr(numeric_only = True)

mask = np.zeros_like(collegecorr)
mask[np.triu_indices_from(mask)] = True

ax2 = sns.heatmap(collegecorr, mask = mask, cmap="mako", annot = True, vmax = 1, vmin = -1)
ax2.set(title="Correlations of College-Related Standardized Test Information")
plt.savefig("../data/Visualizations/heatmapcolleges.png")

# %% [markdown]
# ***Interpretation:*** Interestingly, this heatmap seems to indicate that, as score percentiles increase, the number of applicants increase. However, it also shows that, as the number of applicants increases, the acceptance rate drops, which explains lower acceptance rates among schools with higher score percentiles.

# %%
plt.figure(figsize = (15,5))

plt.hist(satact2019["total"], bins = 20)

plt.title("Distribution of Average SAT Scores by State")

plt.savefig("../data/Visualizations/sathistogram.png");

# %% [markdown]
# ***Interpretation:*** Interestingly, average SAT scores seem to be distributed into three fairly distinct groups. Maine would fall into the group on the left, and it would be interesting to see if there are mandatory test prep courses in high schools based on where they fall in the distribution.

# %%
plt.figure(figsize = (15,5))

plt.hist(satact2019["composite"], bins = 15)

plt.title("Distribution of Average ACT Scores by State")

plt.savefig("../data/Visualizations/acthistogram.png");

# %% [markdown]
# ***Interpretation:*** In a fashion similar to average SAT scores, average ACT scores seem to be distributed into two fairly distinct groups. For ACT scores, Maine ACT takers would fall into the group on the right, completely opposite to the distribution of SAT scores.

# %%
plt.figure(figsize = (15,5))

plt.boxplot(satact2019["total"])

plt.title("Distribution of Average SAT Scores by State")

plt.savefig("../data/Visualizations/satboxplot.png");

# %% [markdown]
# ***Interpretation:*** While this boxplot is redundant with the SAT histogram above, it helps to show the distribution and how it is separated into quartiles as well as its overall range. In this instance, Maine would be in the bottom 25% of states, although this plot would not show precisely where.

# %%
plt.figure(figsize = (15,5))

plt.boxplot(satact2019["composite"])

plt.title("Distribution of Average ACT Scores by State")

plt.savefig("../data/Visualizations/actboxplot.png");

# %% [markdown]
# ***Interpretation:*** Likely due to less commonplace ACT-taking requirements, the top 50% of states has a wider range than the lower 50%, but this also helps us to visualize where the upper quartile is, which is also where Maine testtakers sit.

# %%
plt.figure(figsize = (15, 5))

# Scatter plot
plt.scatter(satactbycollegewithlocation["sat_total_75th_percentile"], satactbycollegewithlocation["accept_rate_float"])

# Create a descriptive title
plt.title("Acceptance Rate of Postsecondary Institutions Based on SAT Score Upper Quartile")

# Add axis labels
plt.ylabel("Acceptance Rate")
plt.xlabel("SAT Score 75th Percentile")

plt.savefig("../data/Visualizations/upperquartileacceptanceratescatter.png");

# %% [markdown]
# ***Interpretation:*** This scatterplot, while still fairly loose, shows that, despite a school being test-optional, the majority of the students at a more selective school will still tend to perform better at standardized tests like the SAT. The reason for using the 75th quartile as a benchmark is that, many college prep sources say that it is best to either hit or exceed the middle 50% of SAT scores at an institution that you are applying to. Citation: https://www.princetonreview.com/college-advice/good-sat-scores

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** The information gathered here would be helpful in advising a student that is looking at applying to colleges and universities. This biggest question that can be answered from the data provided is whether or not an average Maine student should submit their standardized test scores when they are given the option of not submitting them. Based on the data, the Maine test averages do not meet or exceed the average test scores of any institution within the dataset provided. This isn't to say that Maine students should not submit their test scores when applying to higher ed institutions if they perform somewhere above the average. What this information does say is that, on average, a Maine student may be better off omitting their standardized test scores if given the opportunity during the college application process.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
